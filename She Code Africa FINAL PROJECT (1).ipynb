# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
#Importing the dataframe used for analysis
df = pd.read_csv("../Adaaaa/Downloads/life-expectancy-who/Life Expectancy Data.csv")
df2=df.loc[df['Country']=='Nigeria']
df3 = df2[['Adult Mortality','GDP','percentage expenditure','Schooling']]

#This code test for linearity of the the variables adult mortality rate to the gdp of Nigerian economyfrom the year 2005 till 2015
#Linearity help to check if there is a relationship between the dependent and independent variable
a=df3['Adult Mortality']
y=df3['GDP']
plt.scatter(a,y,color ='green')
plt.title('GDP VS ADULT MORTALITY',fontsize=14)
plt.xlabel('Adult Mortality',fontsize=20)
plt.ylabel('GDP', fontsize=20)
plt.show()

#This code test for linearity of the the variables percentage expenditue rate to the gdp of Nigeria economyfrom the year 2005 till 2015

b=df3['percentage expenditure']
y=df3['GDP']
plt.scatter(b,y,color ='blue')
plt.title('GDP VS EXPENDITURE', fontsize=14)
plt.xlabel('expenditure',fontsize=20)
plt.ylabel('GDP', fontsize=20)
plt.show()

#This code test for linearity of the the variables schooling to the gdp of Nigeria economyfrom the year 2005 till 2015

c=df3['Schooling']
y=df3['GDP']
plt.scatter(c,y,color ='red')
plt.title('GDP VS SCHOOLING', fontsize=14)
plt.xlabel('Schooling',fontsize=20)
plt.ylabel('GDP', fontsize=20)
plt.show()

# %%
#This are variables used for the multiple regression
X=df3[['Schooling','percentage expenditure','Adult Mortality']]
y=df3['GDP']
X=sm.add_constant(X)
result= sm.OLS(y,X).fit() 
result.summary()

##EXPLAING THE RESULTS OF THE MULTIPLE REGRESSION MODEL
#The dependent variable GDP is being predicted with independent variables such as schooling,percentage expenditure and adult mortality.
# Out:
# C:\Users\Adaaaa\Anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GDP   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     17.24
# Date:                Thu, 26 Mar 2020   Prob (F-statistic):           0.000120
# Time:                        14:23:52   Log-Likelihood:                -121.91
# No. Observations:                  16   AIC:                             251.8
# Df Residuals:                      12   BIC:                             254.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %%
#ANALYSIS OF THE SUMMARY TABLE.
coef

const -6511.5916

Schooling 833.8695

percentage expenditure 7.6178

Adult Mortality -1.1428

#Looking at the value above,the const of the multiple regression can be seen as -6511.5916
#The predicted value of schooling is given as 833.8695,the model predicts the value of schooling that will give a certain GDP Y.
#The predicted percentage expenditure is given as 7.6178
#Adult mortality was predicted as -1.1428

#THEY MAKE THE COEFFICIENT OF THE MULTIPLE REGRESSION FORMULA,WHICH IN TURN HELPS TO PREDICT THE GDP TAKING ALL IN ABOVE CONSTRAINS INTO CONSIDERATION.
# yi = 0 + b1xi1 + b2xi2 + ... pxip + i for i = 1,2, ... n.
# where yi refers to the dependent variable(GDP) to be predicted by other independent variables(schooling,percentage expenditure,Adult Mortality) and 0 as the constant
#inserting the individual constants manually will give the predicted value of the GDP.
# yi =  -6511.5916 +  -1.1428a +  7.6178b + 833.8695c
# a,b,c refers to each dataframe of the independent variable
# The R-SQUARED ranges from 0 to 1 and measures the proportion of variation in the data that is accounted for in the model. It is useful mainly in explanatory uses of regression where you want to assess how well the model fits the data
# The higher the R-SQUARED the more fit the data,so an R-SQUARED of 0.812 could be said to be perfect.

# %%
#This plots a 3d version of the relationship between the predicted variable with adult mortality and percentage expenditure.
#this is a visualization that shows how an increase in a,b will affect the value of yhat (GDP)

from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
yhat =-6511.5916 - 1.1428*a + 7.6178*b + 833.8695*c
ax = fig.add_subplot(111, projection='3d')
ax.scatter(yhat,a,b)
plt.show()

# %%
#This plots a 3d version of the relationship between the predicted variable with adult mortality and schooling.
#this is a visualization that shows how an increase in a,c will affect the value of yhat (GDP)

from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
yhat =-6511.5916 - 1.1428*a + 7.6178*b + 833.8695*c
ax = fig.add_subplot(111, projection='3d')
ax.scatter(yhat,a,c)
plt.show()

# %%
#This plots a 3d version of the relationship between the predicted variable with percentage expenditure and schooling.
#this is a visualization that shows how an increase in b,c will affect the value of yhat (GDP)

from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
yhat =-6511.5916 - 1.1428*a + 7.6178*b + 833.8695*c
ax = fig.add_subplot(111, projection='3d')
ax.scatter(yhat,b,c)
plt.show()
